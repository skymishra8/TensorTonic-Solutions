# %% [markdown]
# <a href="https://colab.research.google.com/github/skymishra8/TensorTonic-Solutions/blob/main/Student_Stress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('student-lifestyle-and-stress-dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25500 entries, 0 to 25499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_Type        24248 non-null  object
#  1   Sleep_Hours         24167 non-null  float64
#  2   Study_Hours         24223 non-null  float64
#  3   Social_Media_Hours  24188 non-null  float64
#  4   Attendance          24195 non-null  float64
#  5   Exam_Pressure       24230 non-null  float64
#  6   Family_Support      24209 non-null  float64
#  7   Month               24186 non-null  float64
#  8   Stress_Level        25500 non-null  int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.8+ MB

# %%
df
# Out:
#       Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0           school     6.868702     1.711722            3.176942         NaN
# 1           school     8.519088     3.251084            3.880787   93.978465
# 2          college     4.498770     6.306885            2.936172   64.421253
# 3           school     8.591223     2.384922            5.222832   81.868960
# 4          college     5.329293     9.345179            7.815869   85.847982
# ...            ...          ...          ...                 ...         ...
# 25495      college     7.803069     7.328193            2.018277   75.435607
# 25496       school     6.734607     2.680109            3.355559   63.387386
# 25497      college     7.701671     2.631250            2.948252   79.818930
# 25498       school     5.903426     3.450424            6.823894   96.680773
# 25499      college     7.419726     6.442748            3.356066   81.452460
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
x=df.drop(columns=['Stress_Level'])
y=df['Stress_Level']

# %%
categorical_features=["Student_Type"]
numerical_features=[
    "Sleep_Hours",
    "Study_Hours",
    "Social_Media_Hours",
    "Attendance",
    "Exam_Pressure",
    "Family_Support",
    "Month"
]

# %%
preprocessor=ColumnTransformer(
    transformers=[
        ("cat",OneHotEncoder(handle_unknown="ignore"),categorical_features),
        ("num","passthrough",numerical_features)
    ]
)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
model=RandomForestClassifier(
      n_estimators=200,
      random_state=42
)

# %%
pipeline=Pipeline([
        ("preprocessor",preprocessor),
        ("classifier",model)
    ]
)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Student_Type']),
#                                                  ('num', 'passthrough',
#                                                   ['Sleep_Hours', 'Study_Hours',
#                                                    'Social_Media_Hours',
#                                                    'Attendance',
#                                                    'Exam_Pressure',
#                                                    'Family_Support',
#                                                    'Month'])])),
#                 ('classifier',
#                  RandomForestClassifier(n_estimators=200, random_state=42))])

# %%
predictions=pipeline.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
print("Accuracy:",accuracy_score(y_test,predictions)*100)
# Out:
# Accuracy: 81.25490196078431

# %%
print("Classification Report:\n",classification_report(y_test,predictions))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      3571
#            1       0.74      0.58      0.65      1529
#
#     accuracy                           0.81      5100
#    macro avg       0.79      0.75      0.76      5100
# weighted avg       0.81      0.81      0.81      5100

# %%
print("Confusion Matrix:\n",confusion_matrix(y_test,predictions))
# Out:
# Confusion Matrix:
#  [[3250  321]
#  [ 635  894]]

# %%
my_stress={
    "Student_Type":"college",
    "Sleep_Hours":5,
    "Study_Hours":2,
    "Social_Media_Hours":5,
    "Attendance":60,
    "Exam_Pressure":8,
    "Family_Support":5,
    "Month":8

}

# %%
pred=pipeline.predict(pd.DataFrame([my_stress]))

# %%
print("stressed")if pred==1 else print("not stressed")
# Out:
# stressed
